# %%
import pandas as pd

chemin_Buchanan = "./../data/dictionary/1757_Buchanan-J.csv"
df_Buchanan = pd.read_csv(chemin_Buchanan, sep=";")
df_Buchanan
# Out:
#        nbSyll        pron origin warning remarques POS  lineId  pageId
# 0           3     aʹbăcus    NaN     NaN       NaN  n.     2.0      19
# 1           2      ăbăʹft    NaN     NaN       NaN  p.     3.0      19
# 2           3  ăbaiʹſănce     F.     NaN       NaN  n.     4.0      19
# 3           3    ābăʹndon     F.     NaN       NaN  v.     5.0      19
# 4           4  ābăʹndŏned    NaN     NaN       NaN  a.     6.0      19
# ...       ...         ...    ...     ...       ...  ..     ...     ...
# 15795       4  zōŏʹgrăphy     G.     NaN       NaN  n.    19.0     241
# 15796       4  zōŏʹphytès     G.     NaN       NaN  n.    20.0     241
# 15797       4  zōŏʹphŏric     G.     NaN       NaN  n.    21.0     241
# 15798       4  zōŏʹtŏmiſt     G.     NaN       NaN  n.    22.0     241
# 15799       3     zŏʹtĭcā     G.     NaN       NaN  n.    23.0     241
#
# [15800 rows x 8 columns]

# %%
chemin_PronChar = "./../data/dictionary/Buchanan_PronChar_counts.csv" 
df_PronChar = pd.read_csv(chemin_PronChar, sep=";")
print("Max nb value", df_PronChar['char'].value_counts().max())
df_PronChar["graph"] = df_PronChar["graph"].fillna("")
df_PronChar
# Out:
# Max nb value 1
#    char    occ graph
# 0     a   3207     a
# 1     ʹ  12725
# 2     b   2288     b
# 3     ă   4533     a
# 4     c   5500     c
# ..  ...    ...   ...
# 68    á      1     a
# 69    I      1     l
# 70    х      2     x
# 71    р      1     p
# 72    ï      1     i
#
# [73 rows x 3 columns]

# %%
df_PronChar.graph[df_PronChar['char']=="á"].values[0]
# Out:
# 'a'

# %%
def split_pron(pron, df_PronChar):
    df_PronChar
    
    message = ""
    for value in pron:
        res = df_PronChar.graph[df_PronChar['char']==value].values[0]
        message+=str(res)
    return message

# %%
df_Buchanan['resultat'] = df_Buchanan['pron'].apply(lambda x: split_pron(x, df_PronChar))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-b7ceb645d32f> in <module>
# ----> 1 df_Buchanan['resultat'] = df_Buchanan['pron'].apply(lambda x: split_pron(x, df_PronChar))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-69-b7ceb645d32f> in <lambda>(x)
# ----> 1 df_Buchanan['resultat'] = df_Buchanan['pron'].apply(lambda x: split_pron(x, df_PronChar))
#
# <ipython-input-67-62df6e0c475b> in split_pron(pron, df_PronChar)
#       6     message = ""
#       7     for value in pron:
# ----> 8         res = df_PronChar.graph[df_PronChar['char']==value].values[0]
#       9         message+=str(res)
#      10     return message
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# KeyboardInterrupt:

# %%
df_Buchanan
# Out:
#        nbSyll        pron origin warning remarques POS  lineId  pageId
# 0           3     aʹbăcus    NaN     NaN       NaN  n.     2.0      19
# 1           2      ăbăʹft    NaN     NaN       NaN  p.     3.0      19
# 2           3  ăbaiʹſănce     F.     NaN       NaN  n.     4.0      19
# 3           3    ābăʹndon     F.     NaN       NaN  v.     5.0      19
# 4           4  ābăʹndŏned    NaN     NaN       NaN  a.     6.0      19
# ...       ...         ...    ...     ...       ...  ..     ...     ...
# 15795       4  zōŏʹgrăphy     G.     NaN       NaN  n.    19.0     241
# 15796       4  zōŏʹphytès     G.     NaN       NaN  n.    20.0     241
# 15797       4  zōŏʹphŏric     G.     NaN       NaN  n.    21.0     241
# 15798       4  zōŏʹtŏmiſt     G.     NaN       NaN  n.    22.0     241
# 15799       3     zŏʹtĭcā     G.     NaN       NaN  n.    23.0     241
#
# [15800 rows x 8 columns]
